# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       3 drive.mount("/content/gdrive")
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import os
os.chdir("/content/gdrive/MyDrive/Colab Notebooks/semantic_segmentation")

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: wget in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (3.2)
# Requirement already satisfied: pytorch-lightning in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: datasets in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (2.15.0)
# Requirement already satisfied: transformers in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: evaluate in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: seaborn in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (0.12.2)
# Requirement already satisfied: albumentations in c:\users\gokulnath anand\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: torch>=1.12.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (2023.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (23.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pytorch-lightning->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (0.3.7)
# Requirement already satisfied: pandas in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: xxhash in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (0.70.15)
# Requirement already satisfied: aiohttp in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: huggingface-hub>=0.18.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (0.19.4)
# Requirement already satisfied: boto3 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 4)) (1.24.28)
# Requirement already satisfied: regex in c:\users\gokulnath anand\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 4)) (2022.7.9)
# Requirement already satisfied: sentencepiece in c:\users\gokulnath anand\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 4)) (0.1.99)
# Requirement already satisfied: sacremoses in c:\users\gokulnath anand\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 4)) (0.0.43)
# Requirement already satisfied: responses<0.19 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from evaluate->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from seaborn->-r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from albumentations->-r requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from albumentations->-r requirements.txt (line 7)) (0.20.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from albumentations->-r requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from albumentations->-r requirements.txt (line 7)) (4.8.1.78)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: filelock in c:\users\gokulnath anand\anaconda3\lib\site-packages (from huggingface-hub>=0.18.0->datasets->-r requirements.txt (line 3)) (3.9.0)
# Requirement already satisfied: setuptools in c:\users\gokulnath anand\anaconda3\lib\site-packages (from lightning-utilities>=0.8.0->pytorch-lightning->-r requirements.txt (line 2)) (68.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from pandas->datasets->-r requirements.txt (line 3)) (2022.7)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from qudida>=0.0.4->albumentations->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 3)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 3)) (2023.11.17)
# Requirement already satisfied: networkx>=2.8 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations->-r requirements.txt (line 7)) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations->-r requirements.txt (line 7)) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations->-r requirements.txt (line 7)) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations->-r requirements.txt (line 7)) (0.2)
# Requirement already satisfied: sympy in c:\users\gokulnath anand\anaconda3\lib\site-packages (from torch>=1.12.0->pytorch-lightning->-r requirements.txt (line 2)) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from torch>=1.12.0->pytorch-lightning->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\gokulnath anand\anaconda3\lib\site-packages (from tqdm>=4.57.0->pytorch-lightning->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from boto3->transformers->-r requirements.txt (line 4)) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from boto3->transformers->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from boto3->transformers->-r requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: six in c:\users\gokulnath anand\anaconda3\lib\site-packages (from sacremoses->transformers->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: click in c:\users\gokulnath anand\anaconda3\lib\site-packages (from sacremoses->transformers->-r requirements.txt (line 4)) (8.0.4)
# Requirement already satisfied: joblib in c:\users\gokulnath anand\anaconda3\lib\site-packages (from sacremoses->transformers->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from jinja2->torch>=1.12.0->pytorch-lightning->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gokulnath anand\anaconda3\lib\site-packages (from sympy->torch>=1.12.0->pytorch-lightning->-r requirements.txt (line 2)) (1.3.0)

# %%
# import necessary functions
from data_handler.data import get_dataset, get_dataloader
from data_handler.data_visualization_nd_stats import (
    show_samples, 
    show_samples_superposed,
    compute_class_distribution,
    compute_class_weights,
    plot_class_distribution,
    visualize_sample_predictions,
    )
from model_builder.model import *
from utils.utils import visualize_training_plots
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 # import necessary functions
# ----> 2 from data_handler.data import get_dataset, get_dataloader
#       3 from data_handler.data_visualization_nd_stats import (
#       4     show_samples,
#       5     show_samples_superposed,
#    (...)
#       9     visualize_sample_predictions,
#      10     )
#      11 from model_builder.model import *
#
# File ~\Downloads\buildings-and-road-segmentation-main\buildings-and-road-segmentation-main\data_handler\data.py:5
#       3 from torch.utils.data import DataLoader, Dataset
#       4 import albumentations as A
# ----> 5 from transformers import SegformerImageProcessor
#       6 from sklearn.model_selection import train_test_split
#       7 import re
#
# ImportError: cannot import name 'SegformerImageProcessor' from 'transformers' (C:\Users\Gokulnath Anand\anaconda3\Lib\site-packages\transformers\__init__.py)

# %% [markdown]
# # Download the CamSeq1 dataset

# %%
# downloading the dataset
# !python ./utils/download_dataset.py --savedir="./dataset/camvid/"

# %% [markdown]
# # Data Exploration

# %%
train_dataset, val_dataset = get_dataset(
    data_path='./dataset/camvid/',
    val_split=0.2,
    random_state=42,
    feature_extractor_name='nvidia/segformer-b2-finetuned-cityscapes-1024-1024'
    )

# %%
show_samples(train_dataset, 3, random=True)

# %%
show_samples_superposed(train_dataset,3,random=True)

# %%
summary = compute_class_distribution(train_dataset)
plot_class_distribution(train_dataset.id2label.values(),summary)

# %% [markdown]
# # Creating and Fine Tuning the model

# %%
train_dl, val_dl = get_dataloader([train_dataset,val_dataset])
class_weights = compute_class_weights(sum(summary),summary)

# %%
id2label = train_dataset.id2label
trainer, model = train_model(train_dl,
            val_dl,
            class_weights,
            id2label,
            hf_model_name="nvidia/segformer-b2-finetuned-cityscapes-1024-1024",
            ckpt_path='./checkpoints/',
            accelerator_mode='gpu',
            devices=1,
            max_epochs=300,
            log_every_n_steps=8
            )

# %% [markdown]
# ## Resume Training the model

# %%
#train_dl, val_dl = get_dataloader([train_dataset,val_dataset])
#class_weights = compute_class_weights(sum(summary),summary)
#id2label = train_dataset.id2label
trainer, model = train_model(train_dl,
            val_dl,
            class_weights,
            id2label,
            hf_model_name="nvidia/segformer-b2-finetuned-cityscapes-1024-1024",
            ckpt_path='./checkpoints/',
            accelerator_mode='gpu',
            devices=1,
            max_epochs=300,
            log_every_n_steps=8,
            last_ckpt_path='./checkpoints/lightning_logs/version_3/checkpoints/epoch=99-step=800.ckpt',
            resume=True
            )

# %% [markdown]
# ## Evaluating the model

# %%
res = trainer.validate(ckpt_path="best")
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at checkpoints/lightning_logs/version_8/checkpoints/epoch=194-step=1560.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from checkpoint at checkpoints/lightning_logs/version_8/checkpoints/epoch=194-step=1560.ckpt
# Validation: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            0.29798245429992676
#     val_mean_accuracy       0.9053388663729783
#       val_mean_iou           0.682776180739859
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Ploting loss and metrics evolution during training and validation

# %%
visualize_training_plots("./checkpoints_/lightning_logs/version_0/metrics.csv")

# %% [markdown]
# ## Visualizing Prediction Samples

# %%
from model_builder.model import SegFormerFineTuned
from data_handler.data_visualization_nd_stats import (
    visualize_sample_predictions,
    visualize_predictions_superposed,
)

# %%
model = SegFormerFineTuned.load_from_checkpoint('./checkpoints/lightning_logs/version_8/checkpoints/epoch=194-step=1560.ckpt')
colormap = val_dataset.class_colors        
visualize_sample_predictions(val_dl,model,colormap)
# Out:
# Some weights of SegformerForSemanticSegmentation were not initialized from the model checkpoint at nvidia/segformer-b2-finetuned-cityscapes-1024-1024 and are newly initialized because the shapes did not match:
# - decode_head.classifier.weight: found shape torch.Size([19, 768, 1, 1]) in the checkpoint and torch.Size([12, 768, 1, 1]) in the model instantiated
# - decode_head.classifier.bias: found shape torch.Size([19]) in the checkpoint and torch.Size([12]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
visualize_predictions_superposed(val_dl,model,colormap)
